# %%
import pandas as pd

# %%
df = pd.read_csv('study_performance.csv')
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# Plot math_score vs gender using a boxplot
df.boxplot(column='math_score', by='gender')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: title={'center': 'math_score'}, xlabel='gender'>

# %%
# Plot math_score, rading_score, and writing_sore vs gender using a boxplot
df.boxplot(column=['math_score', 'reading_score', 'writing_score'], by='gender')
# Out:
# array([[<Axes: title={'center': 'math_score'}, xlabel='gender'>,
#         <Axes: title={'center': 'reading_score'}, xlabel='gender'>],
#        [<Axes: title={'center': 'writing_score'}, xlabel='gender'>,
#         <Axes: >]], dtype=object)

# %% [markdown]
# ## Generated with Microsoft Copilot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('study_performance.csv')

# Prepare the data
scores = df[['math_score', 'reading_score', 'writing_score', 'gender']]

# Melt the DataFrame to make it suitable for boxplot
scores_melted = pd.melt(scores, id_vars='gender', var_name='score_type', value_name='score')

# Create the boxplot
plt.figure(figsize=(10, 6))
scores_melted.boxplot(column='score', by=['score_type', 'gender'], grid=False)
plt.title('Scores by Gender')
plt.suptitle('')  # Suppress the automatic title
plt.xlabel('Score Type and Gender')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('study_performance.csv')

# Prepare the data
scores = df[['math_score', 'reading_score', 'writing_score', 'gender']]

# Melt the DataFrame to make it suitable for boxplot
scores_melted = pd.melt(scores, id_vars='gender', var_name='score_type', value_name='score')

# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='score_type', y='score', hue='gender', data=scores_melted, palette='Set3')
plt.title('Scores by Gender')
plt.xlabel('Score Type')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('study_performance.csv')

# Prepare the data
scores = df[['math_score', 'reading_score', 'writing_score', 'parental_level_of_education']]

# Melt the DataFrame to make it suitable for boxplot
scores_melted = pd.melt(scores, id_vars='parental_level_of_education', var_name='score_type', value_name='score')

# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='score_type', y='score', hue='parental_level_of_education', data=scores_melted, palette='Set3')
plt.title('Scores by Gender')
plt.xlabel('Score Type')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
df = pd.read_csv('study_performance.csv')

# Prepare the data
scores = df[['math_score', 'reading_score', 'writing_score', 'lunch']]

# Melt the DataFrame to make it suitable for boxplot
scores_melted = pd.melt(scores, id_vars='lunch', var_name='score_type', value_name='score')

# Create the boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='score_type', y='score', hue='lunch', data=scores_melted, palette='Set3')
plt.title('Scores by Gender')
plt.xlabel('Score Type')
plt.ylabel('Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Generated with Gemini

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Path to your CSV file
csv_file_path = "study_performance.csv"

# Read the CSV data into a Pandas DataFrame
data = pd.read_csv(csv_file_path)

# Create the boxplot using seaborn
sns.boxplot(
    x = "gender",
    y = ["math_score", "reading_score", "writing_score"],
    data=data
)

# Customize the plot (optional)
plt.xlabel("Gender")
plt.ylabel("Score")
plt.title("Distribution of Scores by Gender")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32560\1433373703.py in ?()
#       8 # Read the CSV data into a Pandas DataFrame
#       9 data = pd.read_csv(csv_file_path)
#      10
#      11 # Create the boxplot using seaborn
# ---> 12 sns.boxplot(
#      13     x = "gender",
#      14     y = ["math_score", "reading_score", "writing_score"],
#      15     data=data
#
# c:\Users\magitz\AppData\Local\anaconda3\Lib\site-packages\seaborn\categorical.py in ?(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2227     dodge=True, fliersize=5, linewidth=None, whis=1.5, ax=None,
#    2228     **kwargs
#    2229 ):
#    2230
# -> 2231     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2232                           orient, color, palette, saturation,
# ...
